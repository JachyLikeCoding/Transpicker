# %% [markdown]
# # This notebook help you walktrough the steps of TransPicker.

# %% [markdown]
# ## step 1: make coco-style dataset for training and testing.

# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
import glob

# %%
# %%bash
# cd ../src/transpicker/
# pwd
# Out:
# /home/zhangchi/transpicker/Transpicker/src/transpicker

# %%
# %%bash
# python /home/zhangchi/transpicker/Transpicker/src/transpicker/make_coco_dataset.py --coco_path /home/zhangchi/transpicker/Transpicker/data/empiar10028/ --images_path /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/
# Out:
# Namespace(box_width=200, coco_path='/home/zhangchi/transpicker/Transpicker/data/empiar10028/', images_path='/home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/', phase='train')
# There are totally 247 micrographs in the /home/zhangchi/transpicker/Transpicker/data/empiar10028/.
# The No.197 is the split number.
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/548.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/467.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/138.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/542.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/150.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/415.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/066.mrc
# /home/zhangchi/transpicker/Transpicker/data/empiar10028/micrographs/507.mrc
# ...
